# %% [markdown]
# <a href="https://colab.research.google.com/github/guidoivetta/atention-mechanisms-as-baseline-for-VQA/blob/main/COCO_captioner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## El código usado para preprocesar y entrenar está fuertemente inspirado en [este repo](https://github.com/tangbinh/image-captioning).
#
# La computación de este modelo fue hecha en mi propia computadora así que no hay registros en colab, pero es idéntica a la que está en el notebook de `plantVillage_captioner` pero con los datos y las anotaciones de [COCO](https://cocodataset.org/#home).

# %%
# %cd /content/drive/MyDrive/tesis/image-captioning
# !ls

# %%
# !python getTextCaptionsForMultipleImages.py --checkpoint-path checkpoints/show_attend_tell/checkpoint_best.pt --images-path /content/drive/MyDrive/tesis/image-captioning/IMAGES_TO_CAPTION/image
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [2021-11-17 02:31:04] COMMAND: getTextCaptionsForMultipleImages.py --checkpoint-path checkpoints/show_attend_tell/checkpoint_best.pt --images-path /content/drive/MyDrive/tesis/image-captioning/IMAGES_TO_CAPTION/image
# ...

# %%
cat hola.txt
# Out:
# a pink flower in a vase with flowers in it .
# a plant in a garden with leaves and leaves .
# a vase with a bunch of flowers in it
# a white wall with a white wall and a white wall .
# a vase with a plant in it sitting on a wooden surface .
# a vase with flowers in it sitting on a table .

# %%
# !python getCaptionsForOneImage.py --checkpoint-path checkpoints/show_attend_tell/checkpoint_best.pt --images-path /content/drive/MyDrive/tesis/image-captioning/IMAGES_TO_CAPTION/image
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [2021-11-17 02:40:54] COMMAND: getCaptionsForOneImage.py --checkpoint-path checkpoints/show_attend_tell/checkpoint_best.pt --images-path /content/drive/MyDrive/tesis/image-captioning/IMAGES_TO_CAPTION/image
# ...

# %%
from IPython.display import Image
Image(filename='/content/drive/MyDrive/tesis/image-captioning/IMAGES_TO_CAPTION/image/1_CAPTIONED.jpg')
